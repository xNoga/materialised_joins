# %%
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %sql postgresql://appdev@data/appdev
# Out:
# 'Connected: appdev@appdev'

# %% [markdown]
# # Tables and columns in the f1db schema

# %%
# %sql SELECT * from information_schema.tables WHERE table_schema = 'f1db';

# %%
# %sql SELECT * from information_schema.columns WHERE table_schema = 'f1db';

# %% [markdown]
# # On the table *circuits* report:

# %% [markdown]
# ## What type of indices exists for the table and why they are of that type (and not some other type)

# %%
# %sql select * from pg_indexes where tablename = 'circuits'
# Out:
# 3 rows affected.
# [('f1db', 'circuits', 'idx_17102_url', None, 'CREATE UNIQUE INDEX idx_17102_url ON circuits USING btree (url)'),
#  ('f1db', 'circuits', 'circuits_position_idx', None, 'CREATE INDEX circuits_position_idx ON circuits USING gist ("position")'),
#  ('f1db', 'circuits', 'idx_17102_primary', None, 'CREATE UNIQUE INDEX idx_17102_primary ON circuits USING btree (circuitid)')]

# %% [markdown]
# As you can see there exists 3 indexes in the table *circuits*. The indexes *idx_17102_url* and *idx_17102_primary* are both of the type btree. This is probably because the indexes only need to hold integer values and the btree type is the default for indexes in PostgreSQL.
# The index *circuits_position_idx* is the type gist which makes sense because the *position* value for *circuits* is coordinates. GiST trees allows us to build whichever type we want and use <key, pointer> pairs instead of integers (B-trees use integers).
# So GiST trees makes it possible to index on whatever type of data we want instead of just integers for example.

# %% [markdown]
# ## The amount of space each index takes up

# %% [markdown]
# To see the amount of space each index takes up we can just write the following in a postgresql bash:
# > \di+ circuits*;
#
# This would give us the following result:
#
# |Schema |         Name          | Type  | Owner  |  Table   |    Size    |
# |-------|-----------------------|-------|--------|----------|------------|
# |f1db   | circuits_position_idx | index | appdev | circuits | 8192 bytes |
#
# The index *circuits_position_idx* takes up 8192 bytes. The other two indexes are not shown here for some reason. It might be because they are just default indexes. To see them I have type the following in my postgresql bash:
# > \di+
#
# This gives us the size of the last two indexes:
#
# |Schema  |                    Name                    | Type  | Owner  |        Table         |    Size     |
# |---------|--------------------------------------------|-------|--------|---------------------|------------|
# |f1db    | idx_17102_primary                          | index | appdev | circuits             | 16 kB      |
# |f1db    | idx_17102_url                              | index | appdev | circuits             | 16 kB      |

# %% [markdown]
# ## We are talent scouts looking to win over some of the best new drivers there are. But we don't want them too old! Write a query that finds the winner of all the races, but only if they are younger than 38 years. The query should give return the date, driver surname, driver age, track time in milliseconds, race name and circuit name for all races.

# %%
# %%sql SELECT races.date, drivers.surname, EXTRACT(YEAR from AGE(CURRENT_DATE, drivers.dob)) as "age",
# results.milliseconds, races.name as "race name", circuits.name as "circuit name"
# FROM f1db.results
# INNER JOIN f1db.drivers ON
# results.driverid = drivers.driverid
# INNER JOIN f1db.races ON
# results.raceid = races.raceid
# INNER JOIN f1db.circuits ON
# races.circuitid = circuits.circuitid
# WHERE results.position = 1
# AND extract(year from age(CURRENT_DATE, drivers.dob)) < 38
# Out:
# 184 rows affected.
# [(datetime.date(2008, 3, 16), 'Hamilton', 33.0, 5690616, 'Australian Grand Prix', 'Albert Park Grand Prix Circuit'),
#  (datetime.date(2008, 4, 6), 'Massa', 36.0, 5466970, 'Bahrain Grand Prix', 'Bahrain International Circuit'),
#  (datetime.date(2008, 5, 11), 'Massa', 36.0, 5209451, 'Turkish Grand Prix', 'Istanbul Park'),
#  (datetime.date(2008, 5, 25), 'Hamilton', 33.0, 7242742, 'Monaco Grand Prix', 'Circuit de Monaco'),
#  (datetime.date(2008, 6, 8), 'Kubica', 33.0, 5784227, 'Canadian Grand Prix', 'Circuit Gilles Villeneuve'),
#  (datetime.date(2008, 6, 22), 'Massa', 36.0, 5510245, 'French Grand Prix', 'Circuit de Nevers Magny-Cours'),
#  (datetime.date(2008, 7, 6), 'Hamilton', 33.0, 5949440, 'British Grand Prix', 'Silverstone Circuit'),
#  (datetime.date(2008, 7, 20), 'Hamilton', 33.0, 5480874, 'German Grand Prix', 'Hockenheimring'),
#  (datetime.date(2008, 8, 3), 'Kovalainen', 36.0, 5847067, 'Hungarian Grand Prix', 'Hungaroring'),
#  (datetime.date(2008, 8, 24), 'Massa', 36.0, 5732339, 'European Grand Prix', 'Valencia Street Circuit'),
#  (datetime.date(2008, 9, 7), 'Massa', 36.0, 4979394, 'Belgian Grand Prix', 'Circuit de Spa-Francorchamps'),
#  (datetime.date(2008, 9, 14), 'Vettel', 30.0, 5207494, 'Italian Grand Prix', 'Autodromo Nazionale di Monza'),
#  (datetime.date(2008, 9, 28), 'Alonso', 36.0, 7036304, 'Singapore Grand Prix', 'Marina Bay Street Circuit'),
#  (datetime.date(2008, 10, 12), 'Alonso', 36.0, 5421892, 'Japanese Grand Prix', 'Fuji Speedway'),
#  (datetime.date(2008, 10, 19), 'Hamilton', 33.0, 5517403, 'Chinese Grand Prix', 'Shanghai International Circuit'),
#  (datetime.date(2008, 11, 2), 'Massa', 36.0, 5651435, 'Brazilian Grand Prix', 'Autódromo José Carlos Pace'),
#  (datetime.date(2007, 4, 8), 'Alonso', 36.0, 5534930, 'Malaysian Grand Prix', 'Sepang International Circuit'),
#  (datetime.date(2007, 4, 15), 'Massa', 36.0, 5607515, 'Bahrain Grand Prix', 'Bahrain International Circuit'),
#  (datetime.date(2007, 5, 13), 'Massa', 36.0, 5496230, 'Spanish Grand Prix', 'Circuit de Barcelona-Catalunya'),
#  (datetime.date(2007, 5, 27), 'Alonso', 36.0, 6029329, 'Monaco Grand Prix', 'Circuit de Monaco'),
#  (datetime.date(2007, 6, 10), 'Hamilton', 33.0, 6251292, 'Canadian Grand Prix', 'Circuit Gilles Villeneuve'),
#  (datetime.date(2007, 6, 17), 'Hamilton', 33.0, 5469965, 'United States Grand Prix', 'Indianapolis Motor Speedway'),
#  (datetime.date(2007, 7, 22), 'Alonso', 36.0, 7586358, 'European Grand Prix', 'Nürburgring'),
#  (datetime.date(2007, 8, 5), 'Hamilton', 33.0, 5752991, 'Hungarian Grand Prix', 'Hungaroring'),
#  (datetime.date(2007, 8, 26), 'Massa', 36.0, 5202161, 'Turkish Grand Prix', 'Istanbul Park'),
#  (datetime.date(2007, 9, 9), 'Alonso', 36.0, 4717806, 'Italian Grand Prix', 'Autodromo Nazionale di Monza'),
#  (datetime.date(2007, 9, 30), 'Hamilton', 33.0, 7234579, 'Japanese Grand Prix', 'Fuji Speedway'),
#  (datetime.date(2006, 3, 12), 'Alonso', 36.0, 5386205, 'Bahrain Grand Prix', 'Bahrain International Circuit'),
#  (datetime.date(2006, 4, 2), 'Alonso', 36.0, 5667870, 'Australian Grand Prix', 'Albert Park Grand Prix Circuit'),
#  (datetime.date(2006, 5, 14), 'Alonso', 36.0, 5181759, 'Spanish Grand Prix', 'Circuit de Barcelona-Catalunya'),
#  (datetime.date(2006, 5, 28), 'Alonso', 36.0, 6223116, 'Monaco Grand Prix', 'Circuit de Monaco'),
#  (datetime.date(2006, 6, 11), 'Alonso', 36.0, 5151927, 'British Grand Prix', 'Silverstone Circuit'),
#  (datetime.date(2006, 6, 25), 'Alonso', 36.0, 5677308, 'Canadian Grand Prix', 'Circuit Gilles Villeneuve'),
#  (datetime.date(2006, 8, 27), 'Massa', 36.0, 5331082, 'Turkish Grand Prix', 'Istanbul Park'),
#  (datetime.date(2006, 10, 8), 'Alonso', 36.0, 5032413, 'Japanese Grand Prix', 'Suzuka Circuit'),
#  (datetime.date(2006, 10, 22), 'Massa', 36.0, 5513751, 'Brazilian Grand Prix', 'Autódromo José Carlos Pace'),
#  (datetime.date(2005, 3, 20), 'Alonso', 36.0, 5493736, 'Malaysian Grand Prix', 'Sepang International Circuit'),
#  (datetime.date(2005, 4, 3), 'Alonso', 36.0, 5358531, 'Bahrain Grand Prix', 'Bahrain International Circuit'),
#  (datetime.date(2005, 4, 24), 'Alonso', 36.0, 5261921, 'San Marino Grand Prix', 'Autodromo Enzo e Dino Ferrari'),
#  (datetime.date(2005, 5, 29), 'Alonso', 36.0, 5506648, 'European Grand Prix', 'Nürburgring'),
#  (datetime.date(2005, 7, 3), 'Alonso', 36.0, 5482232, 'French Grand Prix', 'Circuit de Nevers Magny-Cours'),
#  (datetime.date(2005, 7, 24), 'Alonso', 36.0, 5188599, 'German Grand Prix', 'Hockenheimring'),
#  (datetime.date(2005, 10, 16), 'Alonso', 36.0, 5993618, 'Chinese Grand Prix', 'Shanghai International Circuit'),
#  (datetime.date(2003, 8, 24), 'Alonso', 36.0, 5941460, 'Hungarian Grand Prix', 'Hungaroring'),
#  (datetime.date(2009, 4, 19), 'Vettel', 30.0, 7063485, 'Chinese Grand Prix', 'Shanghai International Circuit'),
#  (datetime.date(2009, 6, 21), 'Vettel', 30.0, 4969328, 'British Grand Prix', 'Silverstone Circuit'),
#  (datetime.date(2009, 7, 26), 'Hamilton', 33.0, 5903876, 'Hungarian Grand Prix', 'Hungaroring'),
#  (datetime.date(2009, 9, 27), 'Hamilton', 33.0, 6966337, 'Singapore Grand Prix', 'Marina Bay Street Circuit'),
#  (datetime.date(2009, 10, 4), 'Vettel', 30.0, 5300443, 'Japanese Grand Prix', 'Suzuka Circuit'),
#  (datetime.date(2009, 11, 1), 'Vettel', 30.0, 5643414, 'Abu Dhabi Grand Prix', 'Yas Marina Circuit'),
#  (datetime.date(2010, 3, 14), 'Alonso', 36.0, 5960396, 'Bahrain Grand Prix', 'Bahrain International Circuit'),
#  (datetime.date(2010, 4, 4), 'Vettel', 30.0, 5628412, 'Malaysian Grand Prix', 'Sepang International Circuit'),
#  (datetime.date(2010, 5, 30), 'Hamilton', 33.0, 5327620, 'Turkish Grand Prix', 'Istanbul Park'),
#  (datetime.date(2010, 6, 13), 'Hamilton', 33.0, 5633456, 'Canadian Grand Prix', 'Circuit Gilles Villeneuve'),
#  (datetime.date(2010, 6, 27), 'Vettel', 30.0, 6029571, 'European Grand Prix', 'Valencia Street Circuit'),
#  (datetime.date(2010, 7, 25), 'Alonso', 36.0, 5258864, 'German Grand Prix', 'Hockenheimring'),
#  (datetime.date(2010, 8, 29), 'Hamilton', 33.0, 5344268, 'Belgian Grand Prix', 'Circuit de Spa-Francorchamps'),
#  (datetime.date(2010, 9, 12), 'Alonso', 36.0, 4584572, 'Italian Grand Prix', 'Autodromo Nazionale di Monza'),
#  (datetime.date(2010, 9, 26), 'Alonso', 36.0, 7073579, 'Singapore Grand Prix', 'Marina Bay Street Circuit'),
#  (datetime.date(2010, 10, 10), 'Vettel', 30.0, 5427323, 'Japanese Grand Prix', 'Suzuka Circuit'),
#  (datetime.date(2010, 10, 24), 'Alonso', 36.0, 10100810, 'Korean Grand Prix', 'Korean International Circuit'),
#  (datetime.date(2010, 11, 7), 'Vettel', 30.0, 5591803, 'Brazilian Grand Prix', 'Autódromo José Carlos Pace'),
#  (datetime.date(2010, 11, 14), 'Vettel', 30.0, 5976837, 'Abu Dhabi Grand Prix', 'Yas Marina Circuit'),
#  (datetime.date(2011, 3, 27), 'Vettel', 30.0, 5370259, 'Australian Grand Prix', 'Albert Park Grand Prix Circuit'),
#  (datetime.date(2011, 4, 10), 'Vettel', 30.0, 5859832, 'Malaysian Grand Prix', 'Sepang International Circuit'),
#  (datetime.date(2011, 4, 17), 'Hamilton', 33.0, 5818226, 'Chinese Grand Prix', 'Shanghai International Circuit'),
#  (datetime.date(2011, 5, 8), 'Vettel', 30.0, 5417558, 'Turkish Grand Prix', 'Istanbul Park'),
#  (datetime.date(2011, 5, 22), 'Vettel', 30.0, 5943301, 'Spanish Grand Prix', 'Circuit de Barcelona-Catalunya'),
#  (datetime.date(2011, 5, 29), 'Vettel', 30.0, 7778373, 'Monaco Grand Prix', 'Circuit de Monaco'),
#  (datetime.date(2011, 6, 26), 'Vettel', 30.0, 5976169, 'European Grand Prix', 'Valencia Street Circuit'),
#  (datetime.date(2011, 7, 10), 'Alonso', 36.0, 5321196, 'British Grand Prix', 'Silverstone Circuit'),
#  (datetime.date(2011, 7, 24), 'Hamilton', 33.0, 5850334, 'German Grand Prix', 'Nürburgring'),
#  (datetime.date(2011, 8, 28), 'Vettel', 30.0, 5204893, 'Belgian Grand Prix', 'Circuit de Spa-Francorchamps'),
#  (datetime.date(2011, 9, 11), 'Vettel', 30.0, 4846172, 'Italian Grand Prix', 'Autodromo Nazionale di Monza'),
#  (datetime.date(2011, 9, 25), 'Vettel', 30.0, 7146757, 'Singapore Grand Prix', 'Marina Bay Street Circuit'),
#  (datetime.date(2011, 10, 16), 'Vettel', 30.0, 5881994, 'Korean Grand Prix', 'Korean International Circuit'),
#  (datetime.date(2011, 10, 30), 'Vettel', 30.0, 5435002, 'Indian Grand Prix', 'Buddh International Circuit'),
#  (datetime.date(2011, 11, 13), 'Hamilton', 33.0, 5831886, 'Abu Dhabi Grand Prix', 'Yas Marina Circuit'),
#  (datetime.date(2012, 3, 25), 'Alonso', 36.0, 9891812, 'Malaysian Grand Prix', 'Sepang International Circuit'),
#  (datetime.date(2012, 4, 15), 'Rosberg', 32.0, 5786929, 'Chinese Grand Prix', 'Shanghai International Circuit'),
#  (datetime.date(2012, 4, 22), 'Vettel', 30.0, 5710990, 'Bahrain Grand Prix', 'Bahrain International Circuit'),
#  (datetime.date(2012, 5, 13), 'Maldonado', 33.0, 5949145, 'Spanish Grand Prix', 'Circuit de Barcelona-Catalunya'),
#  (datetime.date(2012, 6, 10), 'Hamilton', 33.0, 5549586, 'Canadian Grand Prix', 'Circuit Gilles Villeneuve'),
#  (datetime.date(2012, 6, 24), 'Alonso', 36.0, 6256649, 'European Grand Prix', 'Valencia Street Circuit'),
#  (datetime.date(2012, 7, 22), 'Alonso', 36.0, 5465862, 'German Grand Prix', 'Hockenheimring'),
#  (datetime.date(2012, 7, 29), 'Hamilton', 33.0, 6065503, 'Hungarian Grand Prix', 'Hungaroring'),
#  (datetime.date(2012, 9, 9), 'Hamilton', 33.0, 4781221, 'Italian Grand Prix', 'Autodromo Nazionale di Monza'),
#  (datetime.date(2012, 9, 23), 'Vettel', 30.0, 7226144, 'Singapore Grand Prix', 'Marina Bay Street Circuit'),
#  (datetime.date(2012, 10, 7), 'Vettel', 30.0, 5336242, 'Japanese Grand Prix', 'Suzuka Circuit'),
#  (datetime.date(2012, 10, 14), 'Vettel', 30.0, 5788651, 'Korean Grand Prix', 'Korean International Circuit'),
#  (datetime.date(2012, 10, 28), 'Vettel', 30.0, 5470744, 'Indian Grand Prix', 'Buddh International Circuit'),
#  (datetime.date(2012, 11, 18), 'Hamilton', 33.0, 5755269, 'United States Grand Prix', 'Circuit of the Americas'),
#  (datetime.date(2013, 3, 24), 'Vettel', 30.0, 5936681, 'Malaysian Grand Prix', 'Sepang International Circuit'),
#  (datetime.date(2013, 4, 14), 'Alonso', 36.0, 5786945, 'Chinese Grand Prix', 'Shanghai International Circuit'),
#  (datetime.date(2013, 4, 21), 'Vettel', 30.0, 5760498, 'Bahrain Grand Prix', 'Bahrain International Circuit'),
#  (datetime.date(2013, 5, 12), 'Alonso', 36.0, 5956596, 'Spanish Grand Prix', 'Circuit de Barcelona-Catalunya'),
#  (datetime.date(2013, 5, 26), 'Rosberg', 32.0, 8272056, 'Monaco Grand Prix', 'Circuit de Monaco'),
#  (datetime.date(2013, 6, 9), 'Vettel', 30.0, 5529143, 'Canadian Grand Prix', 'Circuit Gilles Villeneuve'),
#  (datetime.date(2013, 6, 30), 'Rosberg', 32.0, 5579456, 'British Grand Prix', 'Silverstone Circuit'),
#  (datetime.date(2013, 7, 7), 'Vettel', 30.0, 6074711, 'German Grand Prix', 'Nürburgring'),
#  (datetime.date(2013, 7, 28), 'Hamilton', 33.0, 6149445, 'Hungarian Grand Prix', 'Hungaroring'),
#  (datetime.date(2013, 8, 25), 'Vettel', 30.0, 5022196, 'Belgian Grand Prix', 'Circuit de Spa-Francorchamps'),
#  (datetime.date(2013, 9, 8), 'Vettel', 30.0, 4713352, 'Italian Grand Prix', 'Autodromo Nazionale di Monza'),
#  (datetime.date(2013, 9, 22), 'Vettel', 30.0, 7153132, 'Singapore Grand Prix', 'Marina Bay Street Circuit'),
#  (datetime.date(2013, 10, 6), 'Vettel', 30.0, 6193701, 'Korean Grand Prix', 'Korean International Circuit'),
#  (datetime.date(2013, 10, 13), 'Vettel', 30.0, 5209301, 'Japanese Grand Prix', 'Suzuka Circuit'),
#  (datetime.date(2013, 10, 27), 'Vettel', 30.0, 5472187, 'Indian Grand Prix', 'Buddh International Circuit'),
#  (datetime.date(2013, 11, 3), 'Vettel', 30.0, 5886106, 'Abu Dhabi Grand Prix', 'Yas Marina Circuit'),
#  (datetime.date(2013, 11, 17), 'Vettel', 30.0, 5957148, 'United States Grand Prix', 'Circuit of the Americas'),
#  (datetime.date(2013, 11, 24), 'Vettel', 30.0, 5556300, 'Brazilian Grand Prix', 'Autódromo José Carlos Pace'),
#  (datetime.date(2014, 3, 16), 'Rosberg', 32.0, 5578710, 'Australian Grand Prix', 'Albert Park Grand Prix Circuit'),
#  (datetime.date(2014, 3, 30), 'Hamilton', 33.0, 6025974, 'Malaysian Grand Prix', 'Sepang International Circuit'),
#  (datetime.date(2014, 4, 6), 'Hamilton', 33.0, 5982743, 'Bahrain Grand Prix', 'Bahrain International Circuit'),
#  (datetime.date(2014, 4, 20), 'Hamilton', 33.0, 5608338, 'Chinese Grand Prix', 'Shanghai International Circuit'),
#  (datetime.date(2014, 5, 11), 'Hamilton', 33.0, 6065155, 'Spanish Grand Prix', 'Circuit de Barcelona-Catalunya'),
#  (datetime.date(2014, 5, 25), 'Rosberg', 32.0, 6567661, 'Monaco Grand Prix', 'Circuit de Monaco'),
#  (datetime.date(2014, 6, 8), 'Ricciardo', 28.0, 5952830, 'Canadian Grand Prix', 'Circuit Gilles Villeneuve'),
#  (datetime.date(2014, 6, 22), 'Rosberg', 32.0, 5274976, 'Austrian Grand Prix', 'Red Bull Ring'),
#  (datetime.date(2014, 7, 6), 'Hamilton', 33.0, 8812094, 'British Grand Prix', 'Silverstone Circuit'),
#  (datetime.date(2014, 7, 20), 'Rosberg', 32.0, 5622914, 'German Grand Prix', 'Hockenheimring'),
#  (datetime.date(2014, 7, 27), 'Ricciardo', 28.0, 6785058, 'Hungarian Grand Prix', 'Hungaroring'),
#  (datetime.date(2014, 8, 24), 'Ricciardo', 28.0, 5076556, 'Belgian Grand Prix', 'Circuit de Spa-Francorchamps'),
#  (datetime.date(2014, 9, 7), 'Hamilton', 33.0, 4750236, 'Italian Grand Prix', 'Autodromo Nazionale di Monza'),
#  (datetime.date(2014, 9, 21), 'Hamilton', 33.0, 7204795, 'Singapore Grand Prix', 'Marina Bay Street Circuit'),
#  (datetime.date(2014, 10, 5), 'Hamilton', 33.0, 6703021, 'Japanese Grand Prix', 'Suzuka Circuit'),
#  (datetime.date(2014, 10, 12), 'Hamilton', 33.0, 5510744, 'Russian Grand Prix', 'Sochi Autodrom'),
#  (datetime.date(2014, 11, 2), 'Hamilton', 33.0, 6004785, 'United States Grand Prix', 'Circuit of the Americas'),
#  (datetime.date(2014, 11, 9), 'Rosberg', 32.0, 5402555, 'Brazilian Grand Prix', 'Autódromo José Carlos Pace'),
#  (datetime.date(2014, 11, 23), 'Hamilton', 33.0, 5942619, 'Abu Dhabi Grand Prix', 'Yas Marina Circuit'),
#  (datetime.date(2015, 3, 15), 'Hamilton', 33.0, 5514067, 'Australian Grand Prix', 'Albert Park Grand Prix Circuit'),
#  (datetime.date(2015, 3, 29), 'Vettel', 30.0, 6065793, 'Malaysian Grand Prix', 'Sepang International Circuit'),
#  (datetime.date(2015, 4, 12), 'Hamilton', 33.0, 5982008, 'Chinese Grand Prix', 'Shanghai International Circuit'),
#  (datetime.date(2015, 4, 19), 'Hamilton', 33.0, 5705809, 'Bahrain Grand Prix', 'Bahrain International Circuit'),
#  (datetime.date(2015, 5, 10), 'Rosberg', 32.0, 6072555, 'Spanish Grand Prix', 'Circuit de Barcelona-Catalunya'),
#  (datetime.date(2015, 5, 24), 'Rosberg', 32.0, 6558420, 'Monaco Grand Prix', 'Circuit de Monaco'),
#  (datetime.date(2015, 6, 7), 'Hamilton', 33.0, 5513145, 'Canadian Grand Prix', 'Circuit Gilles Villeneuve'),
#  (datetime.date(2015, 6, 21), 'Rosberg', 32.0, 5416930, 'Austrian Grand Prix', 'Red Bull Ring'),
#  (datetime.date(2015, 7, 5), 'Hamilton', 33.0, 5487729, 'British Grand Prix', 'Silverstone Circuit'),
#  (datetime.date(2015, 7, 26), 'Vettel', 30.0, 6369985, 'Hungarian Grand Prix', 'Hungaroring'),
#  (datetime.date(2015, 8, 23), 'Hamilton', 33.0, 5020387, 'Belgian Grand Prix', 'Circuit de Spa-Francorchamps'),
#  (datetime.date(2015, 9, 6), 'Hamilton', 33.0, 4680688, 'Italian Grand Prix', 'Autodromo Nazionale di Monza'),
#  (datetime.date(2015, 9, 20), 'Vettel', 30.0, 7282118, 'Singapore Grand Prix', 'Marina Bay Street Circuit'),
#  (datetime.date(2015, 9, 27), 'Hamilton', 33.0, None, 'Japanese Grand Prix', 'Suzuka Circuit'),
#  (datetime.date(2015, 10, 11), 'Hamilton', 33.0, 5831024, 'Russian Grand Prix', 'Sochi Autodrom'),
#  (datetime.date(2015, 10, 25), 'Hamilton', 33.0, 6652703, 'United States Grand Prix', 'Circuit of the Americas'),
#  (datetime.date(2015, 11, 1), 'Rosberg', 32.0, 6155038, 'Mexican Grand Prix', 'Autódromo Hermanos Rodríguez'),
#  (datetime.date(2015, 11, 15), 'Rosberg', 32.0, 5469090, 'Brazilian Grand Prix', 'Autódromo José Carlos Pace'),
#  (datetime.date(2015, 11, 29), 'Rosberg', 32.0, 5910175, 'Abu Dhabi Grand Prix', 'Yas Marina Circuit'),
#  (datetime.date(2016, 3, 20), 'Rosberg', 32.0, 6495565, 'Australian Grand Prix', 'Albert Park Grand Prix Circuit'),
#  (datetime.date(2016, 4, 3), 'Rosberg', 32.0, 5614696, 'Bahrain Grand Prix', 'Bahrain International Circuit'),
#  (datetime.date(2016, 4, 17), 'Rosberg', 32.0, 5933891, 'Chinese Grand Prix', 'Shanghai International Circuit'),
#  (datetime.date(2016, 5, 1), 'Rosberg', 32.0, 5561997, 'Russian Grand Prix', 'Sochi Autodrom'),
#  (datetime.date(2016, 5, 15), 'Verstappen', 20.0, 6100017, 'Spanish Grand Prix', 'Circuit de Barcelona-Catalunya'),
#  (datetime.date(2016, 5, 29), 'Hamilton', 33.0, 7169133, 'Monaco Grand Prix', 'Circuit de Monaco'),
#  (datetime.date(2016, 6, 12), 'Hamilton', 33.0, 5465296, 'Canadian Grand Prix', 'Circuit Gilles Villeneuve'),
#  (datetime.date(2016, 6, 19), 'Rosberg', 32.0, 5572366, 'European Grand Prix', 'Baku City Circuit'),
#  (datetime.date(2016, 7, 3), 'Hamilton', 33.0, 5258107, 'Austrian Grand Prix', 'Red Bull Ring'),
#  (datetime.date(2016, 7, 10), 'Hamilton', 33.0, 5695831, 'British Grand Prix', 'Silverstone Circuit'),
#  (datetime.date(2016, 7, 24), 'Hamilton', 33.0, 6030115, 'Hungarian Grand Prix', 'Hungaroring'),
#  (datetime.date(2016, 7, 31), 'Hamilton', 33.0, 5444200, 'German Grand Prix', 'Hockenheimring'),
#  (datetime.date(2016, 8, 28), 'Rosberg', 32.0, 6291058, 'Belgian Grand Prix', 'Circuit de Spa-Francorchamps'),
#  (datetime.date(2016, 9, 4), 'Rosberg', 32.0, 4648089, 'Italian Grand Prix', 'Autodromo Nazionale di Monza'),
#  (datetime.date(2016, 9, 18), 'Rosberg', 32.0, 6948950, 'Singapore Grand Prix', 'Marina Bay Street Circuit'),
#  (datetime.date(2016, 10, 2), 'Ricciardo', 28.0, 5832776, 'Malaysian Grand Prix', 'Sepang International Circuit'),
#  (datetime.date(2016, 10, 9), 'Rosberg', 32.0, 5203333, 'Japanese Grand Prix', 'Suzuka Circuit'),
#  (datetime.date(2016, 10, 23), 'Hamilton', 33.0, 5892618, 'United States Grand Prix', 'Circuit of the Americas'),
#  (datetime.date(2016, 10, 30), 'Hamilton', 33.0, 6031402, 'Mexican Grand Prix', 'Autódromo Hermanos Rodríguez'),
#  (datetime.date(2016, 11, 13), 'Hamilton', 33.0, 10861335, 'Brazilian Grand Prix', 'Autódromo José Carlos Pace'),
#  (datetime.date(2016, 11, 27), 'Hamilton', 33.0, 5884013, 'Abu Dhabi Grand Prix', 'Yas Marina Circuit'),
#  (datetime.date(2017, 3, 26), 'Vettel', 30.0, 5051672, 'Australian Grand Prix', 'Albert Park Grand Prix Circuit'),
#  (datetime.date(2017, 4, 9), 'Hamilton', 33.0, 5856158, 'Chinese Grand Prix', 'Shanghai International Circuit'),
#  (datetime.date(2017, 4, 16), 'Vettel', 30.0, 5633374, 'Bahrain Grand Prix', 'Bahrain International Circuit'),
#  (datetime.date(2017, 4, 30), 'Bottas', 28.0, 5288743, 'Russian Grand Prix', 'Sochi Autodrom'),
#  (datetime.date(2017, 5, 14), 'Hamilton', 33.0, 5756497, 'Spanish Grand Prix', 'Circuit de Barcelona-Catalunya'),
#  (datetime.date(2017, 5, 28), 'Vettel', 30.0, 6284340, 'Monaco Grand Prix', 'Circuit de Monaco'),
#  (datetime.date(2017, 6, 11), 'Hamilton', 33.0, 5585154, 'Canadian Grand Prix', 'Circuit Gilles Villeneuve'),
#  (datetime.date(2017, 6, 25), 'Ricciardo', 28.0, 7435573, 'Azerbaijan Grand Prix', 'Baku City Circuit'),
#  (datetime.date(2017, 7, 9), 'Bottas', 28.0, 4908523, 'Austrian Grand Prix', 'Red Bull Ring'),
#  (datetime.date(2017, 7, 16), 'Hamilton', 33.0, 4887430, 'British Grand Prix', 'Silverstone Circuit'),
#  (datetime.date(2017, 7, 30), 'Vettel', 30.0, 5986713, 'Hungarian Grand Prix', 'Hungaroring'),
#  (datetime.date(2017, 8, 27), 'Hamilton', 33.0, 5082820, 'Belgian Grand Prix', 'Circuit de Spa-Francorchamps'),
#  (datetime.date(2017, 9, 3), 'Hamilton', 33.0, 4532312, 'Italian Grand Prix', 'Autodromo Nazionale di Monza'),
#  (datetime.date(2017, 9, 17), 'Hamilton', 33.0, 7403544, 'Singapore Grand Prix', 'Marina Bay Street Circuit'),
#  (datetime.date(2017, 10, 1), 'Verstappen', 20.0, 5401290, 'Malaysian Grand Prix', 'Sepang International Circuit')]

# %% [markdown]
# ## Describe the query using EXPLAIN ANALYZE with at least 5 lines of text. Answer at least the following:

# %%
# %%sql EXPLAIN ANALYSE
# SELECT races.date, drivers.surname, EXTRACT(YEAR from AGE(CURRENT_DATE, drivers.dob)) as "age",
# results.milliseconds, races.name as "race name", circuits.name as "circuit name"
# FROM f1db.results
# INNER JOIN f1db.drivers ON
# results.driverid = drivers.driverid
# INNER JOIN f1db.races ON
# results.raceid = races.raceid
# INNER JOIN f1db.circuits ON
# races.circuitid = circuits.circuitid
# WHERE results.position = 1
# AND extract(year from age(CURRENT_DATE, drivers.dob)) < 38
# Out:
# 22 rows affected.
# [('Hash Join  (cost=82.13..815.57 rows=324 width=66) (actual time=10.826..25.115 rows=184 loops=1)',),
#  ('  Hash Cond: (races.circuitid = circuits.circuitid)',),
#  ('  ->  Hash Join  (cost=78.48..803.83 rows=324 width=50) (actual time=10.121..22.904 rows=184 loops=1)',),
#  ('        Hash Cond: (results.raceid = races.raceid)',),
#  ('        ->  Hash Join  (cost=38.53..759.78 rows=324 width=27) (actual time=1.151..12.523 rows=184 loops=1)',),
#  ('              Hash Cond: (results.driverid = drivers.driverid)',),
#  ('              ->  Seq Scan on results  (cost=0.00..708.96 rows=974 width=24) (actual time=0.011..6.661 rows=974 loops=1)',),
#  ('                    Filter: ("position" = 1)',),
#  ('                    Rows Removed by Filter: 22703',),
#  ('              ->  Hash  (cost=35.03..35.03 rows=280 width=19) (actual time=1.121..1.121 rows=60 loops=1)',),
#  ('                    Buckets: 1024  Batches: 1  Memory Usage: 12kB',),
#  ('                    ->  Seq Scan on drivers  (cost=0.00..35.03 rows=280 width=19) (actual time=0.015..0.839 rows=60 loops=1)',),
#  ("                          Filter: (date_part('year'::text, age((CURRENT_DATE)::timestamp with time zone, (dob)::timestamp with time zone)) < '38'::double precision)",),
#  ('                          Rows Removed by Filter: 781',),
#  ('        ->  Hash  (cost=27.76..27.76 rows=976 width=39) (actual time=8.946..8.946 rows=976 loops=1)',),
#  ('              Buckets: 1024  Batches: 1  Memory Usage: 79kB',),
#  ('              ->  Seq Scan on races  (cost=0.00..27.76 rows=976 width=39) (actual time=0.020..4.551 rows=976 loops=1)',),
#  ('  ->  Hash  (cost=2.73..2.73 rows=73 width=28) (actual time=0.689..0.689 rows=73 loops=1)',),
#  ('        Buckets: 1024  Batches: 1  Memory Usage: 13kB',),
#  ('        ->  Seq Scan on circuits  (cost=0.00..2.73 rows=73 width=28) (actual time=0.011..0.334 rows=73 loops=1)',),
#  ('Planning time: 0.587 ms',),
#  ('Execution time: 25.911 ms',)]

# %% [markdown]
# ### How many calls are you making?
#
# I'm not quite sure what "calls" are referring to in this case. But I'm guessing it means how many different operations/actions are we doing in this query. If this is the case we can simply just count the lines where an operation is used. All operations except the first will start with "->".
# First we use 3 operations on joins. Then we scan on *results* for position = 1. This removes 22703 rows.
# PostgreSQL then does some hashing.
# Then we scan on *drivers* where their age is less than 38. This removes 781 rows.
# Agian postgreSQL does some hashing.
# Then a scan on *races* with hashing again.
# And then last a scan on *circuits*.
# In total we make 10 "calls".
# If calls refer to how many rows each "operation" found you can simply just count all the "rows=x".
#
# ### How long does it take to perform the query?
#
# The query uses 0.318 ms on planning time and 3.971 ms on execution time.

# %% [markdown]
# ## Create a materialized view of your query. Using EXPLAIN ANALYZE try to query the view. Write at least 5 lines of text explaining what's going on and why the query execution time changed.

# %%
# %%sql CREATE MATERIALIZED VIEW race_winners_cache AS
# SELECT races.date, drivers.surname, EXTRACT(YEAR from AGE(CURRENT_DATE, drivers.dob)) as "age",
# results.milliseconds, races.name as "race name", circuits.name as "circuit name"
# FROM f1db.results
# INNER JOIN f1db.drivers ON
# results.driverid = drivers.driverid
# INNER JOIN f1db.races ON
# results.raceid = races.raceid
# INNER JOIN f1db.circuits ON
# races.circuitid = circuits.circuitid
# WHERE results.position = 1
# AND extract(year from age(CURRENT_DATE, drivers.dob)) < 38
# Out:
# 184 rows affected.
# []

# %%
# %sql EXPLAIN ANALYSE SELECT * FROM race_winners_cache
# Out:
# 3 rows affected.
# [('Seq Scan on race_winners_cache  (cost=0.00..4.84 rows=184 width=69) (actual time=0.012..0.818 rows=184 loops=1)',),
#  ('Planning time: 0.050 ms',),
#  ('Execution time: 1.605 ms',)]

# %% [markdown]
# When creating a materialized view we cache the result of the query. That means that we don't actually have to run the query each time but instaed just save the result in cache and return the result almost instantly. This gives us a huge advantage in the amount of the it takes to retrieve the information we want but it also means that the query returns the same result every time. If the data in the database change we would get the wrong information out. We would have to manually run the "REFRESH MATERIALIZED VIEW" command on the view.
# As you can see in the result the planning and execution time has been reduced drastically which is the advantage of a materialized view.
